# %%
import pandas as pd

# %%
data = [['a',34],['a',34],['a',34]]

# %%
data
# Out:
# [['a', 34], ['a', 34], ['a', 34]]

# %%
pd.DataFrame(data, columns=["Name", "Marks"])
# Out:
#   Name  Marks
# 0    a     34
# 1    a     34
# 2    a     34

# %%
#Dataframe from disctionary
dictdata={"a":[4,5,6], "b":[0,6,8]}
df = pd.DataFrame(dictdata)
df
# Out:
#    a  b
# 0  4  0
# 1  5  6
# 2  6  8

# %%
#Dataframe from numpy
import numpy as np
arr = np.array([[1,2],[3,4]])
df = pd.DataFrame(arr, columns=["A","B"])
df
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df = pd.read_csv("data.csv")
df
# Out:
#                  Actor                      Film  Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023           Action
# 1          Salman Khan           Tiger Zinda Hai  2017           Action
# 2           Aamir Khan                    Dangal  2016        Biography
# 3        Ranbir Kapoor                Brahmastra  2022          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018         Thriller
# 6        Rajkummar Rao                     Stree  2018    Horror Comedy
# 7       Hrithik Roshan                       War  2019           Action
# 8         Akshay Kumar                Good Newwz  2019           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                   1050   7.2
# 1                    565   6.0
# 2                   2024   8.4
# 3                    431   5.6
# 4                    585   7.0
# 5                    111   8.3
# 6                    180   7.5
# 7                    475   6.5
# 8                    318   7.0
# 9                    266   5.9
# 10                   201   6.1
# 11                   342   8.2

# %%
#Read from Json
df = pd.read_json("data.json")
df
# Out:
#                                                users  \
# 0  {'id': 1, 'name': 'Amit', 'friends': [2, 3], '...
# 1  {'id': 2, 'name': 'Priya', 'friends': [1, 4], ...
# 2  {'id': 3, 'name': 'Rahul', 'friends': [1], 'li...
# 3  {'id': 4, 'name': 'Sara', 'friends': [2], 'lik...
#
#                                              pages
# 0         {'id': 101, 'name': 'Python Developers'}
# 1  {'id': 102, 'name': 'Data Science Enthusiasts'}
# 2         {'id': 103, 'name': 'AI & ML Community'}
# 3               {'id': 104, 'name': 'Web Dev Hub'}

# %%
df.head()
# Out:
#                                                users  \
# 0  {'id': 1, 'name': 'Amit', 'friends': [2, 3], '...
# 1  {'id': 2, 'name': 'Priya', 'friends': [1, 4], ...
# 2  {'id': 3, 'name': 'Rahul', 'friends': [1], 'li...
# 3  {'id': 4, 'name': 'Sara', 'friends': [2], 'lik...
#
#                                              pages
# 0         {'id': 101, 'name': 'Python Developers'}
# 1  {'id': 102, 'name': 'Data Science Enthusiasts'}
# 2         {'id': 103, 'name': 'AI & ML Community'}
# 3               {'id': 104, 'name': 'Web Dev Hub'}

# %%
df.tail()
# Out:
#                                                users  \
# 0  {'id': 1, 'name': 'Amit', 'friends': [2, 3], '...
# 1  {'id': 2, 'name': 'Priya', 'friends': [1, 4], ...
# 2  {'id': 3, 'name': 'Rahul', 'friends': [1], 'li...
# 3  {'id': 4, 'name': 'Sara', 'friends': [2], 'lik...
#
#                                              pages
# 0         {'id': 101, 'name': 'Python Developers'}
# 1  {'id': 102, 'name': 'Data Science Enthusiasts'}
# 2         {'id': 103, 'name': 'AI & ML Community'}
# 3               {'id': 104, 'name': 'Web Dev Hub'}

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   users   4 non-null      object
#  1   pages   4 non-null      object
# dtypes: object(2)
# memory usage: 196.0+ bytes

# %%
df.describe()
# Out:
#                                                     users  \
# count                                                   4
# unique                                                  4
# top     {'id': 1, 'name': 'Amit', 'friends': [2, 3], '...
# freq                                                    1
#
#                                            pages
# count                                          4
# unique                                         4
# top     {'id': 101, 'name': 'Python Developers'}
# freq                                           1
