# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot") #choose style
# Data
labels = ["Sachin", "Sehwag", "Kohli", "Yuvraj"]
runs = [18000, 8000, 12000, 9500]

plt.title("Career Runs of Indian Batsmen")
plt.pie(runs, labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e0a7826de0>,
#   <matplotlib.patches.Wedge at 0x1e0a7824b90>,
#   <matplotlib.patches.Wedge at 0x1e0a785c740>,
#   <matplotlib.patches.Wedge at 0x1e0a785cc20>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
plt.pie(
    runs,
    labels=labels,
    wedgeprops={'edgecolor': 'black', 'linewidth': 2, 'linestyle': '--'}
)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e0aad19910>,
#   <matplotlib.patches.Wedge at 0x1e0a787acc0>,
#   <matplotlib.patches.Wedge at 0x1e0aad1a000>,
#   <matplotlib.patches.Wedge at 0x1e0aad1a5a0>],
#  [Text(0.4083169456239889, 1.0214094536062885, 'Sachin'),
#   Text(-1.0706592766215497, 0.2523662286919946, 'Sehwag'),
#   Text(-0.5074751936730054, -0.9759451459003964, 'Kohli'),
#   Text(0.8899187482945414, -0.6465637025335375, 'Yuvraj')])

# %%
explode = [0.1, 0, 0, 0]  # Only highlight Sachin's slice

plt.pie(runs, labels=labels, explode=explode, shadow=True, startangle=100, autopct='%1.1f%%')
plt.title("Exploded Pie Example")
plt.show()
